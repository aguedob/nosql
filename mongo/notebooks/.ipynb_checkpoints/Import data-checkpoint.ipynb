# %%
import pandas as pd
import json
import numpy as np    

# Load basic CI relational data
ci_df = pd.read_json("../sql/Configuration_Item.json")
attributes_df = pd.read_json("../sql/Attribute.json")

# Load performance relational data
rules_df = pd.read_json("../sql/perfRules.json")
rule_instances_df = pd.read_json("../sql/perfRuleInstances.json")
perf_data_df = pd.read_json("../sql/perfRuleData.json")

# Load monitors relational data
monitors_df = pd.read_json("../sql/Monitors.json")
monitor_instances_df = pd.read_json("../sql/MonitorInstances.json")
monitor_instance_states_df=pd.read_json("../sql/MonitorInstanceStates.json")
health_states_df=pd.read_json("../sql/HealthStates.json").set_index('state_id')

# Load alert instances relational data
alert_instances_df = pd.read_json("../sql/AlertInstances.json")
alert_states_df = pd.read_json("../sql/AlertStates.json").set_index("state_id")



# Merge CI and attributes data into one dataframe
ci_att_df = pd.merge(ci_df,attributes_df,on="ci_id")
cp=ci_att_df.pivot(index="name", columns="att_name")
cp.columns = ['ci_id','ci_id2','ci_id3','device_type','env','ip_address']
cp.drop(columns=['ci_id2', 'ci_id3'], inplace=True)
configuration_items=cp.reset_index()
monitor_instances_df = pd.merge(monitor_instances_df,monitors_df,on="monitor_id")


# Merge performance dataframes
rule_instances_df.rename(columns={'per_ruleId':'ruleId'}, inplace=True)
rule_instances_df = pd.merge(ci_df,rule_instances_df,on="ci_id")
rule_instances = pd.merge(rule_instances_df,rules_df,on="ruleId")
rule_instances.sort_values('ci_id')


alert_instances_df = pd.merge(alert_instances_df,monitor_instances_df,on="mon_isntance_id" )
alert_instances_df = pd.merge(alert_instances_df,ci_df, on="ci_id")
alert_instances_df = alert_instances_df.loc[:,['alert_name','alert_description','name_y','state_change_date','priority']]
alert_instances_df.rename(columns={'name_y':'configuration_item'}, inplace=True)

# %%
configuration_item_documents= []
alert_documents = []

for ci_index, configuration_item in configuration_items.iterrows():
    ci = json.loads(configuration_item.to_json())
    
    # Attach performance rules instances
    ci["performance_rules"]=[]
    for rule_index, rule_instance in rule_instances[rule_instances["ci_id"]==ci["ci_id"]].loc[:,'ruleId':'rule_description'].iterrows():
        rule = json.loads(rule_instance.to_json())
        
        # Attach performance data 
        data = []
        for perf_data_index, perf_data in perf_data_df[perf_data_df["perf_rule_instId"]==rule["ruleId"]].loc[:,'value':'date'].iterrows():
            d = json.loads(perf_data.to_json())
            data.append(d)
        rule["data"]=data
        ci["performance_rules"].append(rule)
        
    # Attach monitor instances
    ci["monitors"]= []
    
    for monitor_index, monitor_instance in monitor_instances_df[monitor_instances_df["ci_id"]==ci["ci_id"]].loc[:,['mon_isntance_id','name','description']].iterrows():
        monitor = json.loads(monitor_instance.to_json())
        
        # Attach health state for each monitor instance
        states = []
        
        for monitor_instance_index, monitor_instance_state in monitor_instance_states_df[monitor_instance_states_df["mon_isntance_id"]==monitor["mon_isntance_id"]].loc[:,['state_change_date','health_State_id']].iterrows():
            state_id=int(monitor_instance_state["health_State_id"])-1
            monitor_instance_state["health_State_id"] = health_states_df.iloc[state_id].state_name
            currentState = json.loads(monitor_instance_state.to_json())
            states.append(currentState)
        
        monitor["states"]=states
        
        ci["monitors"].append(monitor)
    
    configuration_item_documents.append(ci)
   
for alert_index, alert_row in alert_instances_df.iterrows():
    alert = json.loads(alert_row.to_json())
    priority_id=int(alert_row["priority"])-1
    alert['priority']= alert_states_df.iloc[priority_id].state_name
    alert_documents.append(alert)

# %%
with open('../nosql/cis.json', 'w') as fout:
    fout.write(json.dumps(configuration_item_documents, indent=4))
with open('../nosql/alerts.json', 'w') as fout:
    fout.write(json.dumps(alert_documents, indent=4))

# %%
alert_instances_df
# Out:
#            alert_name                     alert_description  \
# 0   Heartbeat failure  The device is not sending heartbeats
# 1   Heartbeat failure  The device is not sending heartbeats
# 2   Heartbeat failure  The device is not sending heartbeats
# 3   Heartbeat failure  The device is not sending heartbeats
# 4   Heartbeat failure  The device is not sending heartbeats
# ..                ...                                   ...
# 95  Heartbeat failure  The device is not sending heartbeats
# 96  Heartbeat failure  The device is not sending heartbeats
# 97  Heartbeat failure  The device is not sending heartbeats
# 98  Heartbeat failure  The device is not sending heartbeats
# 99  Heartbeat failure  The device is not sending heartbeats
#
#       configuration_item    state_change_date  severity
# 0   impossiblejamb.local  2020-05-23T03:44:08         1
# 1     rubberyclock.local  2020-05-23T03:44:37         1
# 2           wrytug.local  2020-05-23T03:44:27         1
# 3        worstblip.local  2020-05-23T03:44:12         1
# 4        lastbuyer.local  2020-05-23T03:44:21         1
# ..                   ...                  ...       ...
# 95        cutestep.local  2020-05-23T03:44:37         1
# 96  worrisomeflare.local  2020-05-23T03:44:16         1
# 97   vivaciousjunk.local  2020-05-23T03:44:25         1
# 98   celebratedday.local  2020-05-23T03:44:51         1
# 99    grouchybaker.local  2020-05-23T03:44:28         1
#
# [100 rows x 5 columns]

# %%
monitor_instances_df
# Out:
#      mon_isntance_id  ci_id  monitor_id  \
# 0                  1      1          31
# 1                  2      2          31
# 2                  3      3          31
# 3                  4      4          31
# 4                  5      5          31
# ..               ...    ...         ...
# 785              670     90          10
# 786              700    100          10
# 787              730     37          10
# 788              760     72          10
# 789              790     35          10
#
#                                               name  \
# 0                                Heartbeat Monitor
# 1                                Heartbeat Monitor
# 2                                Heartbeat Monitor
# 3                                Heartbeat Monitor
# 4                                Heartbeat Monitor
# ..                                             ...
# 785  Operating System Total Percent Interrupt Time
# 786  Operating System Total Percent Interrupt Time
# 787  Operating System Total Percent Interrupt Time
# 788  Operating System Total Percent Interrupt Time
# 789  Operating System Total Percent Interrupt Time
#
#                                            description  \
# 0              This monitor checks if the device is up
# 1              This monitor checks if the device is up
# 2              This monitor checks if the device is up
# 3              This monitor checks if the device is up
# 4              This monitor checks if the device is up
# ..                                                 ...
# 785  The total percentage of interrupt time (for al...
# 786  The total percentage of interrupt time (for al...
# 787  The total percentage of interrupt time (for al...
# 788  The total percentage of interrupt time (for al...
# 789  The total percentage of interrupt time (for al...
#
#                                       alert_name  \
# 0                              Heartbeat failure
# 1                              Heartbeat failure
# 2                              Heartbeat failure
# 3                              Heartbeat failure
# 4                              Heartbeat failure
# ..                                           ...
# 785  Total Percentage Interrupt Time is too high
# 786  Total Percentage Interrupt Time is too high
# 787  Total Percentage Interrupt Time is too high
# 788  Total Percentage Interrupt Time is too high
# 789  Total Percentage Interrupt Time is too high
#
#                                      alert_description
# 0                 The device is not sending heartbeats
# 1                 The device is not sending heartbeats
# 2                 The device is not sending heartbeats
# 3                 The device is not sending heartbeats
# 4                 The device is not sending heartbeats
# ..                                                 ...
# 785  The threshold for the Processor\\% Interrupt T...
# 786  The threshold for the Processor\\% Interrupt T...
# 787  The threshold for the Processor\\% Interrupt T...
# 788  The threshold for the Processor\\% Interrupt T...
# 789  The threshold for the Processor\\% Interrupt T...
#
# [790 rows x 7 columns]

# %%
alert_instances_df3
# Out:
#     alert_instance_id  severity  priority  alert_State_id  \
# 0                   1         1         1               1
# 1                   2         1         1               1
# 2                   3         1         1               1
# 3                   4         1         1               1
# 4                   5         1         1               1
# ..                ...       ...       ...             ...
# 95                 96         1         1               1
# 96                 97         1         1               1
# 97                 98         1         1               1
# 98                 99         1         1               1
# 99                100         1         1               1
#
#       state_change_date  mon_isntance_id  ci_id  monitor_id  \
# 0   2020-05-23T03:44:08                1      1          31
# 1   2020-05-23T03:44:37                2      2          31
# 2   2020-05-23T03:44:27                3      3          31
# 3   2020-05-23T03:44:12                4      4          31
# 4   2020-05-23T03:44:21                5      5          31
# ..                  ...              ...    ...         ...
# 95  2020-05-23T03:44:37               96     96          31
# 96  2020-05-23T03:44:16               97     97          31
# 97  2020-05-23T03:44:25               98     98          31
# 98  2020-05-23T03:44:51               99     99          31
# 99  2020-05-23T03:44:28              100    100          31
#
#                name_x                              description  \
# 0   Heartbeat Monitor  This monitor checks if the device is up
# 1   Heartbeat Monitor  This monitor checks if the device is up
# 2   Heartbeat Monitor  This monitor checks if the device is up
# 3   Heartbeat Monitor  This monitor checks if the device is up
# 4   Heartbeat Monitor  This monitor checks if the device is up
# ..                ...                                      ...
# 95  Heartbeat Monitor  This monitor checks if the device is up
# 96  Heartbeat Monitor  This monitor checks if the device is up
# 97  Heartbeat Monitor  This monitor checks if the device is up
# 98  Heartbeat Monitor  This monitor checks if the device is up
# 99  Heartbeat Monitor  This monitor checks if the device is up
#
#            alert_name                     alert_description  \
# 0   Heartbeat failure  The device is not sending heartbeats
# 1   Heartbeat failure  The device is not sending heartbeats
# 2   Heartbeat failure  The device is not sending heartbeats
# 3   Heartbeat failure  The device is not sending heartbeats
# 4   Heartbeat failure  The device is not sending heartbeats
# ..                ...                                   ...
# 95  Heartbeat failure  The device is not sending heartbeats
# 96  Heartbeat failure  The device is not sending heartbeats
# 97  Heartbeat failure  The device is not sending heartbeats
# 98  Heartbeat failure  The device is not sending heartbeats
# 99  Heartbeat failure  The device is not sending heartbeats
#
#       configuration_item
# 0   impossiblejamb.local
# 1     rubberyclock.local
# 2           wrytug.local
# 3        worstblip.local
# 4        lastbuyer.local
# ..                   ...
# 95        cutestep.local
# 96  worrisomeflare.local
# 97   vivaciousjunk.local
# 98   celebratedday.local
# 99    grouchybaker.local
#
# [100 rows x 13 columns]

# %%
alert_states_df
# Out:
#          state_name
# state_id
# 1               New
# 2          Assigned
# 3            Closed
